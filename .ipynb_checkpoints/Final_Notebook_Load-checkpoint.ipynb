# %% [markdown]
# # Part 3 - Load

# %%
#!pip install webdriver_manager

# %%
# Import Dependencies
import pandas as pd
import matplotlib.pyplot as plt
import os
import numpy as np
import requests
import json
from pprint import pprint
import datetime as dt
from sqlalchemy import create_engine
from bs4 import BeautifulSoup
import requests
from webdriver_manager.chrome import ChromeDriverManager
import quandl
import scipy

# %% [markdown]
# ### Final data for interest rate 2019

# %%
# Get final dataset from previous notebooks
# %run Transform/Interest_rate_2019.ipynb

# %%
# Call final table
MortgageRate2019
# Out:
#       Date  Estimated variable mortgage rate
# 0  01/2019                            2.7680
# 1  02/2019                            2.8075
# 2  03/2019                            2.8875
# 3  04/2019                            2.8800
# 4  05/2019                            2.8820
# 5  06/2019                            2.9000
# 6  07/2019                            2.9000
# 7  08/2019                            2.9000
# 8  09/2019                            2.9000
# 9  10/2019                            2.9000

# %% [markdown]
# ### Final data for interest  2020

# %%
# %run Transform/Interest_rate_2020.ipynb

# %%
MortgageRate2020
# Out:
#       Date  Estimated variable mortgage rate
# 0  01/2020                            2.8960
# 1  02/2020                            2.8900
# 2  03/2020                            2.6100
# 3  04/2020                            2.3420
# 4  05/2020                            2.2400
# 5  06/2020                            2.1125
# 6  07/2020                            2.0200
# 7  08/2020                            1.9625
# 8  09/2020                            1.9275
# 9  10/2020                            1.8860

# %% [markdown]
# ### Final data for

# %%
# %run Transform/Price_Houses_sold_ON_2019.ipynb
# Out:
# {'dataset': {'collapse': None,
#              'column_index': None,
#              'column_names': ['Date',
#                               '1st 20%',
#                               '2nd 40%',
#                               '3rd 60%',
#                               '4th 80%',
#                               'Median',
#                               'Average',
#                               'Units'],
#              'data': [['2020-11-30',
#                        550000.0,
#                        640000.0,
#                        756000.0,
#                        940000.0,
#                        695000.0,
#                        841281.0,
#                        1726.0],
#                       ['2020-10-31',
#                        520000.0,
#                        645000.0,
#                        755000.0,
#                        1016000.0,
#                        695000.0,
#                        872838.0,
#                        1452.0],
# ...

# %%
response_final_2019_sort
# Out:
#        Date   Average   Units
# 0   01/2019  952417.0  1544.0
# 1   02/2019  969348.0  1370.0
# 2   03/2019  822919.0  1090.0
# 3   04/2019  781375.0  1537.0
# 4   05/2019  940509.0  1808.0
# 5   06/2019  907690.0  1315.0
# 6   07/2019  872848.0  1379.0
# 7   08/2019  874600.0  1243.0
# 8   09/2019  840612.0  1355.0
# 9   10/2019  845374.0  1286.0
# 10  11/2019  822800.0  1287.0

# %% [markdown]
# ### Final data for

# %%
# %run Transform/Price_Houses_sold_ON_2020.ipynb
# Out:
# {'dataset': {'collapse': None,
#              'column_index': None,
#              'column_names': ['Date',
#                               '1st 20%',
#                               '2nd 40%',
#                               '3rd 60%',
#                               '4th 80%',
#                               'Median',
#                               'Average',
#                               'Units'],
#              'data': [['2020-11-30',
#                        550000.0,
#                        640000.0,
#                        756000.0,
#                        940000.0,
#                        695000.0,
#                        841281.0,
#                        1726.0],
#                       ['2020-10-31',
#                        520000.0,
#                        645000.0,
#                        755000.0,
#                        1016000.0,
#                        695000.0,
#                        872838.0,
#                        1452.0],
# ...

# %%
response_final_2020_sort
# Out:
#        Date   Average   Units
# 0   01/2020  844830.0  1144.0
# 1   02/2020  853468.0  1184.0
# 2   03/2020  898243.0   943.0
# 3   04/2020  832860.0  1365.0
# 4   05/2020  903186.0  1098.0
# 5   06/2020  978462.0  1317.0
# 6   07/2020  792402.0  1547.0
# 7   08/2020  830097.0  1299.0
# 8   09/2020  855467.0  1579.0
# 9   10/2020  872838.0  1452.0
# 10  11/2020  841281.0  1726.0

# %% [markdown]
# ### Data for

# %%
# %run Transform/Units_sold_BC_transf_2019.ipynb
# Out:
# {'dataset': {'collapse': None,
#              'column_index': None,
#              'column_names': ['Date',
#                               '1st 20%',
#                               '2nd 40%',
#                               '3rd 60%',
#                               '4th 80%',
#                               'Median',
#                               'Average',
#                               'Units'],
#              'data': [['2020-11-30',
#                        830000.0,
#                        1052000.0,
#                        1450000.0,
#                        1812000.0,
#                        1250000.0,
#                        1477176.0,
#                        587.0],
#                       ['2020-10-31',
#                        866000.0,
#                        1277000.0,
#                        1500000.0,
#                        1950000.0,
#                        1400000.0,
#                        1568317.0,
#                        712.0],
# ...

# %%
response_final_2019_sort
# Out:
#        Date    Average  Units
# 0   01/2019  1649891.0  681.0
# 1   02/2019  1666028.0  605.0
# 2   03/2019  1496844.0  594.0
# 3   04/2019  1438884.0  560.0
# 4   05/2019  1725362.0  655.0
# 5   06/2019  1567301.0  658.0
# 6   07/2019  1619494.0  682.0
# 7   08/2019  1807158.0  574.0
# 8   09/2019  2005425.0  663.0
# 9   10/2019  1584840.0  672.0
# 10  11/2019  1569846.0  556.0

# %% [markdown]
# ##Data for

# %%
# %run Transform/Units_sold_BC_transf_2020.ipynb
# Out:
# {'dataset': {'collapse': None,
#              'column_index': None,
#              'column_names': ['Date',
#                               '1st 20%',
#                               '2nd 40%',
#                               '3rd 60%',
#                               '4th 80%',
#                               'Median',
#                               'Average',
#                               'Units'],
#              'data': [['2020-11-30',
#                        830000.0,
#                        1052000.0,
#                        1450000.0,
#                        1812000.0,
#                        1250000.0,
#                        1477176.0,
#                        587.0],
#                       ['2020-10-31',
#                        866000.0,
#                        1277000.0,
#                        1500000.0,
#                        1950000.0,
#                        1400000.0,
#                        1568317.0,
#                        712.0],
# ...

# %%
response_final_2020_sort
# Out:
#        Date    Average  Units
# 0   01/2020  1651315.0  596.0
# 1   02/2020  1606519.0  548.0
# 2   03/2020  1614033.0  651.0
# 3   04/2020  1403234.0  555.0
# 4   05/2020  1487319.0  572.0
# 5   06/2020  1591293.0  522.0
# 6   07/2020  1482528.0  604.0
# 7   08/2020  1461194.0  520.0
# 8   09/2020  1423546.0  562.0
# 9   10/2020  1568317.0  712.0
# 10  11/2020  1477176.0  587.0

# %% [markdown]
# ### Data

# %%
#!pip install nest_asyncio

# %%
import nest_asyncio
nest_asyncio.apply()

# %%
# %run Transform/web_scrapping.ipynb
# Out:
# <!DOCTYPE html>
# <html class="no-js" dir="ltr" lang="en" xmlns="http://www.w3.org/1999/xhtml">
#  <head>
#   <meta charset="utf-8"/>
#   <base href="https://www150.statcan.gc.ca/t1/tbl1/"/>
#   <title>
#    New housing price index, monthly
#   </title>
#   <link href="http://purl.org/dc/terms/" rel="schema.dcterms"/>
#   <meta content="New housing price index (NHPI). Monthly data are available from January 1981. The table presents data for the most recent reference period and the last four periods. The base period for the index is (201612=100)." name="description">
#    <meta content="Construction" name="keywords"/>
#    <meta content="New housing price index, monthly" name="dcterms.title"/>
#    <meta content="eng" name="dcterms.language" title="ISO639-2"/>
#    <meta content="2020-11-20" name="dcterms.issued" title="W3CDTF"/>
#    <meta content="2020-11-20" name="dcterms.modified" title="W3CDTF"/>
#    <meta content="none" name="dcterms.subject" title="gcstc"/>
# ...

# %%
resultsDF
# Out:
#      Months TempData
# 0   01/2019    103.5
# 1   02/2019    103.5
# 2   03/2019    103.6
# 3   04/2019    103.6
# 4   05/2019    103.6
# 5   06/2019    103.8
# 6   07/2019    103.3
# 7   08/2019    103.3
# 8   09/2019    104.0
# 9   10/2019    104.2
# 10  11/2019    104.4
# 11  12/2019    104.7
# 12  01/2020    104.6
# 13  02/2020    105.4
# 14  03/2020    105.9
# 15  04/2020    106.0
# 16  05/2020    106.3
# 17  06/2020    106.4
# 18  07/2020    106.7
# 19  08/2020    107.4
# 20  09/2020    108.6
# 21  10/2020    109.7

# %% [markdown]
# ## Data

# %%
# %run Transform/CovidCases_ON.ipynb

# %%
Reported_cases_per_month_ON
# Out:
#     Number_of_Cases     Date
# 0                 3  01/2020
# 1                14  02/2020
# 2              3006  03/2020
# 3             14970  04/2020
# 4             11050  05/2020
# 5              6266  06/2020
# 6              4061  07/2020
# 7              3139  08/2020
# 8             10133  09/2020
# 9             24627  10/2020
# 10             1436  11/2020

# %%
Elep_engine=create_engine("postgres://xbrqktwe:E_nywn4IJhz89kqxwG3M498kv8qnq4Z6@rajje.db.elephantsql.com:5432/xbrqktwe")

# %%
resultsDF.to_sql(name="web_scrapping",schema="public", index=False, if_exists="replace", method="multi", con=Elep_engine)

# %%
response_final_2019_sort.to_sql(name="Units_sold_BC_transf_2019",schema="public", index=False, if_exists="replace", method="multi", con=Elep_engine)

# %%
response_final_2020_sort.to_sql(name="Units_sold_BC_transf_2020",schema="public", index=False, if_exists="replace", method="multi", con=Elep_engine)

# %%
Reported_cases_per_month_ON.to_sql(name="CovidCases_On",schema="public", index=False, if_exists="replace", method="multi", con=Elep_engine)

# %%
MortgageRate2019.to_sql(name="Interest_rate_2019",schema="public", index=False, if_exists="replace", method="multi", con=Elep_engine)

# %%
MortgageRate2020.to_sql(name="Interest_rate_2020",schema="public", index=False, if_exists="replace", method="multi", con=Elep_engine)

# %%
response_final_2019_sort.to_sql(name="Price_Houses_sold_ON_2019",schema="public", index=False, if_exists="replace", method="multi", con=Elep_engine)
