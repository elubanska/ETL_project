# %%
#Importing pandas & OS
import pandas as pd
import os

# %%
#Retrieving CSV file
file_path = os.path.join("Extract _CSV_Files/COVID_Cases_ON.csv")
datafile_df = pd.read_csv(file_path)
#Changing case_reported_date to data format
datafile_df['Case_Reported_Date'] = pd.to_datetime(datafile_df['Case_Reported_Date'])
datafile_df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-7-f72439e982eb> in <module>
#       1 #Retrieving CSV file
#       2 file_path = os.path.join("../Extract_CSV_Files/COVID_Cases_ON.csv")
# ----> 3 datafile_df = pd.read_csv(file_path)
#       4 #Changing case_reported_date to data format
#       5 datafile_df['Case_Reported_Date'] = pd.to_datetime(datafile_df['Case_Reported_Date'])
#
# ...

# %%
#Creating a column & extracting the month
datafile_df['month'] = pd.DatetimeIndex(datafile_df['Case_Reported_Date']).month
datafile_df.head()
# Out:
#    Row_ID Accurate_Episode_Date Case_Reported_Date Test_Reported_Date  \
# 0       1            2020-10-31         2020-11-01         2020-11-01
# 1       2            2020-10-17         2020-10-30         2020-10-30
# 2       3            2020-10-30         2020-11-02         2020-11-02
# 3       4            2020-10-30         2020-11-01         2020-11-01
# 4       5            2020-10-30         2020-11-01         2020-11-01
#
#   Specimen_Date Age_Group Client_Gender Case_AcquisitionInfo      Outcome1  \
# 0    2020-11-01       20s          MALE                   OB  Not Resolved
# 1    2020-10-30       40s          MALE                   OB      Resolved
# 2    2020-10-31       50s          MALE                   OB  Not Resolved
# 3    2020-11-01       20s          MALE                   OB  Not Resolved
# 4    2020-10-31       40s          MALE                   OB  Not Resolved
#
#   Outbreak_Related               Reporting_PHU Reporting_PHU_Address  \
# ...

# %%
#Creating final dataframe with relevant info

COVID_ON_GroupBy_Month = datafile_df.groupby("month")
Reported_cases_per_month_ON = pd.DataFrame(COVID_ON_GroupBy_Month["month"].count())
Date = ["01/2020","02/2020","03/2020","04/2020","05/2020","06/2020","07/2020","08/2020","09/2020","10/2020","11/2020"]
Reported_cases_per_month_ON["Date"] = Date
Reported_cases_per_month_ON = Reported_cases_per_month_ON.reset_index(drop=True)
Reported_cases_per_month_ON.columns = ["Number_of_Cases","Date"]
Reported_cases_per_month_ON
# Out:
#     Number_of_Cases     Date
# 0                 3  01/2020
# 1                14  02/2020
# 2              3006  03/2020
# 3             14970  04/2020
# 4             11050  05/2020
# 5              6266  06/2020
# 6              4061  07/2020
# 7              3139  08/2020
# 8             10133  09/2020
# 9             24627  10/2020
# 10             1436  11/2020
